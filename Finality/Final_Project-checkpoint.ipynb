# %% [markdown]
# # Google Play Store
# Данные за июнь 2021 года.
#
# **Воржев Артём**\
# **04-06-2023**\
# **Email: vorzhevartemvorzhev@gmail.com**\
# **GitHub:** https://github.com/Vorzh

# %% [markdown]
# # Анализ Google Play Store:
#     Анализ категорий приложений, установок, рейтингов и тд.

# %% [markdown]
# ![image.png](1362170315_b7e6d9b0c24824bd6cd5dde0657f3c04.png)

# %% [markdown]
# # Шаг 1: Импортируем библиотеки

# %%
# Базовые библиотеки
import pandas as pd #главная библиотека в Python для работы с данными
import numpy as np #для математических вычеслений
import seaborn as sns #библиотека для создания статистических графиков
import matplotlib.pyplot as plt #Модуль помогает автоматически создавать оси, фигуры и другие компоненты, не задумываясь о том, как это происходит
# %matplotlib inline
import plotly as px #библиотека для визуализации данных

# Статистика
from scipy import stats #предназначенная для решения научных и математических задач

# Машинное обучение
from sklearn.preprocessing import MinMaxScaler #Стандартизация или удаление среднего и масштабирование дисперсии
from sklearn.preprocessing import StandardScaler #Стандартизация или удаление среднего и масштабирование дисперсии

# Дашборд
import missingno as msno #помогает визуализировать недостающие данные в датафреймах Pandas и определить частоту расположения пропущенных значений в датасете
from skimpy import skim #инструмент для создания сводной статистики

# %% [markdown]
# # Шаг 2: Загружаем данные

# %%
df = pd.read_csv("Google-Playstore.csv") #загружаем данные из csv файла

# %% [markdown]
# # Шаг 3: Изучаем данные

# %%
df.head(5) #смотрим верхние 5 строк
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# 2              50.0                58  True    0.0  ...
# 3              10.0                19  True    0.0  ...
# 4             100.0               478  True    0.0  ...
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35
#
# [5 rows x 24 columns]

# %%
df.info() #выводим информацию о данных в столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 361.8+ MB

# %%
df.columns #смотрим названия колонок
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
df.shape #размерность (строки, столбцы)
# Out:
# (2312944, 24)

# %% [markdown]
# ## Просмотр переменных

# %%
df.dtypes #тип данных
# Out:
# App Name              object
# App Id                object
# Category              object
# Rating               float64
# Rating Count         float64
# Installs              object
# Minimum Installs     float64
# Maximum Installs       int64
# Free                    bool
# Price                float64
# Currency              object
# Size                  object
# Minimum Android       object
# Developer Id          object
# Developer Website     object
# Developer Email       object
# Released              object
# Last Updated          object
# Content Rating        object
# Privacy Policy        object
# Ad Supported            bool
# In App Purchases        bool
# Editors Choice          bool
# Scraped Time          object
# dtype: object

# %% [markdown]
# #### Давайте построим график недостающих нулевых значений

# %%
msno.matrix(df,sparkline=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Удаляем значения

# %% [markdown]
# 1. Столбцами с наибольшим процентом нулевых значений являются "Developer Website" и "Privacy Policy", которые не являются существенными для анализа. Следовательно, мы можем удалить эти столбцы.
#
# 2. Для других столбцов, таких как "Размер", "Currency", "Installs", "Мinimum Installs", "Developer Id" и "Developer Email", мы можем удалить строки с небольшими нулевыми значениями, поскольку они существенно не повлияют на общий анализ.
#
# 3. Такие столбцы, как "Released", "Rating" и "Rating Count", важны, и лучше заполнить их нулевыми значениями, а не удалять их.

# %%
df.dropna(subset=['App Name','Installs','Minimum Installs','Currency','Size','Developer Id','Developer Email'], inplace=True)

# %%
df.drop(columns=["Developer Website", "Privacy Policy"], inplace=True)

# %%
df.isnull().sum()
# Out:
# App Name                0
# App Id                  0
# Category                0
# Rating              22572
# Rating Count        22572
# Installs                0
# Minimum Installs        0
# Maximum Installs        0
# Free                    0
# Price                   0
# Currency                0
# Size                    0
# Minimum Android      6530
# Developer Id            0
# Developer Email         0
# Released            70748
# Last Updated            0
# Content Rating          0
# Ad Supported            0
# In App Purchases        0
# Editors Choice          0
# Scraped Time            0
# dtype: int64

# %% [markdown]
# ## Дублированные значения
# Очищаем каждый ряд
#
# Проверка наличия дубликатов в названии приложения

# %%
duplicated = df["App Name"].duplicated().any()
duplicated
# Out:
# True

# %%
df["App Name"].value_counts(ascending=False)
# Out:
# Tic Tac Toe                     382
# Calculator                      261
# Flashlight                      256
# BMI Calculator                  201
# Age Calculator                  190
#                                ...
# Foodiz Resto                      1
# Astra OtoReward                   1
# MedTerm Dictionary                1
# Urban garden and sowing.          1
# Biliyor Musun - Sonsuz Yarış      1
# Name: App Name, Length: 2177593, dtype: int64

# %% [markdown]
# Основываясь на выводах из предыдущей ячейки, можно сделать вывод, что столбец "App Name" содержит повторяющиеся строки.\
# Давайте проверим, идентичны данные в этих строках или нет

# %%
df[df["App Name"] == "Calculator"]
# Out:
#            App Name                               App Id      Category  \
# 13555    Calculator               com.asdapps.calculator  Productivity
# 20965    Calculator                 adel.kalu.calculator         Tools
# 21568    Calculator                calculatorswaya.voice         Tools
# 32421    Calculator         com.mobiletrendzy.calculator         Tools
# 51292    Calculator  appinventor.ai_miraanrai.calculator     Education
# ...             ...                                  ...           ...
# 2252643  Calculator        com.spectensys.calculatorfree         Tools
# 2258272  Calculator           com.manikshakya.calculator         Tools
# 2276810  Calculator             dhiman.nikhil.calculator       Finance
# 2278518  Calculator                  com.jangolabs.vcalc         Tools
# 2296273  Calculator           com.toddperkins.calculator         Tools
#
#          Rating  Rating Count    Installs  Minimum Installs  Maximum Installs  \
# 13555       5.0           5.0         10+              10.0                45
# 20965       0.0           0.0          5+               5.0                 7
# 21568       0.0           0.0          1+               1.0                 3
# 32421       5.0           8.0        100+             100.0               492
# 51292       5.0           6.0         10+              10.0                14
# ...         ...           ...         ...               ...               ...
# 2252643     4.3        4949.0  1,000,000+         1000000.0           1238356
# 2258272     0.0           0.0          1+               1.0                 3
# 2276810     5.0          11.0         10+              10.0                28
# 2278518     0.0           0.0        100+             100.0               149
# 2296273     0.0           0.0         10+              10.0                45
#
#          Free  Price  ... Minimum Android                Developer Id  \
# 13555    True    0.0  ...      4.1 and up                    ASD Apps
# 20965    True    0.0  ...      4.1 and up                   Adel Kalu
# 21568    True    0.0  ...      4.1 and up  Alcea Technologies Pvt Ltd
# 32421    True    0.0  ...      4.0 and up              Mobile Trendzy
# 51292    True    0.0  ...      2.1 and up                  Miraan Rai
# ...       ...    ...  ...             ...                         ...
# 2252643  True    0.0  ...      2.2 and up                  Spectensys
# 2258272  True    0.0  ...      4.1 and up                Manik Shakya
# 2276810  True    0.0  ...      4.1 and up               Nikhil Dhiman
# 2278518  True    0.0  ...      4.1 and up                  Jango Labs
# 2296273  True    0.0  ...      5.0 and up                Todd Perkins
#
#                        Developer Email      Released  Last Updated  \
# 13555       abdulkadir.dalal@gmail.com  Jul 10, 2016  Jul 10, 2016
# 20965            adel.b.kalu@gmail.com  Nov 30, 2020  Dec 01, 2020
# 21568    support@alceatechnologies.com  Nov 15, 2019  Nov 16, 2019
# 32421           help@mobiletrendzy.com  Sep 22, 2016  Sep 22, 2016
# 51292              Miraanrai@gmail.com  Feb 21, 2019  Feb 28, 2020
# ...                                ...           ...           ...
# 2252643           spectensys@gmail.com  Dec 21, 2013  Aug 23, 2017
# 2258272        hotpop_manik1@yahoo.com   Jul 6, 2020  Jul 07, 2020
# 2276810     nikhildhiman3644@gmail.com  Oct 14, 2017  Oct 14, 2017
# 2278518          support@jangolabs.com  Jun 18, 2017  Jun 19, 2017
# 2296273           todd@toddperkins.com  Jan 25, 2018  Jan 25, 2018
#
#         Content Rating Ad Supported In App Purchases  Editors Choice  \
# 13555         Everyone        False            False           False
# 20965         Everyone        False            False           False
# 21568         Everyone        False            False           False
# 32421         Everyone         True            False           False
# 51292         Everyone        False            False           False
# ...                ...          ...              ...             ...
# 2252643       Everyone        False            False           False
# 2258272       Everyone        False            False           False
# 2276810       Everyone        False            False           False
# 2278518       Everyone        False            False           False
# 2296273       Everyone        False            False           False
#
#                 Scraped Time
# 13555    2021-06-15 20:32:46
# 20965    2021-06-15 20:40:02
# 21568    2021-06-15 20:40:37
# 32421    2021-06-15 20:51:43
# 51292    2021-06-15 21:10:26
# ...                      ...
# 2252643  2021-06-16 12:06:10
# 2258272  2021-06-16 12:11:12
# 2276810  2021-06-16 12:27:29
# 2278518  2021-06-16 12:28:57
# 2296273  2021-06-16 12:44:34
#
# [261 rows x 22 columns]

# %%
duplicated = df["App Id"].duplicated().any()
duplicated
# Out:
# False

# %%
df["App Id"].value_counts(ascending=False)
# Out:
# com.ishakwe.gakondo                    1
# com.avai.amp.dewtour                   1
# com.myhomebuy                          1
# com.apocalipseescatologia.app          1
# com.puzzlegame.wordconnect             1
#                                       ..
# id.compro.virtualcompetition           1
# com.fitivity.basketball_point_guard    1
# smartgr.gardenshower.ideas             1
# com.euroland.mobiletools.ae_nbad       1
# com.yyazilim.biliyormusun              1
# Name: App Id, Length: 2312548, dtype: int64

# %% [markdown]
# # **Замена типа данных:**

# %%
df["Installs"].unique()
# Out:
# array(['10+', '5,000+', '50+', '100+', '1,000+', '500+', '50,000+',
#        '10,000+', '1+', '500,000+', '100,000+', '5+', '10,000,000+',
#        '1,000,000+', '5,000,000+', '0+', '100,000,000+', '50,000,000+',
#        '1,000,000,000+', '500,000,000+', '5,000,000,000+',
#        '10,000,000,000+'], dtype=object)

# %% [markdown]
# Нужно изменить тип данных в столбце "Installs"

# %%
# Удаляем символы
df["Installs"] = df["Installs"].str.split("+").str[0]
df.Installs
# Out:
# 0               10
# 1            5,000
# 2               50
# 3               10
# 4              100
#             ...
# 2312939    100,000
# 2312940        100
# 2312941        100
# 2312942      1,000
# 2312943        100
# Name: Installs, Length: 2312548, dtype: object

# %%
# Заменяем запятые "," в столбце "Installs"
df["Installs"].replace(",", "", regex=True, inplace=True) 
df.Installs
# Out:
# 0              10
# 1            5000
# 2              50
# 3              10
# 4             100
#             ...
# 2312939    100000
# 2312940       100
# 2312941       100
# 2312942      1000
# 2312943       100
# Name: Installs, Length: 2312548, dtype: object

# %%
# Меняем тип данных \ была проблема с изменением типа данных на int, нашел решение 'np.int64' для windows
df["Installs"] = df["Installs"].astype(np.int64)

# %%
df["Installs"].unique()
# Out:
# array([         10,        5000,          50,         100,        1000,
#                500,       50000,       10000,           1,      500000,
#             100000,           5,    10000000,     1000000,     5000000,
#                  0,   100000000,    50000000,  1000000000,   500000000,
#         5000000000, 10000000000], dtype=int64)

# %% [markdown]
# **Объеденяем игровые категории в одну:**

# %%
df = df.replace({'Category': ('Action','Adventure','Arcade','Card','Casual',\
                              'Puzzle','Racing','Role Playing','Simulation','Strategy')}, 'Games')

# %% [markdown]
# # Задачи:
# 1. Какие 10 лучших категорий которые устанавливаются из магазина Google Play?
# 2. Какие категории чаще всего устанавливаются в топ-10?
# 3. Какая категория имеет самый высокий рейтинг?
# 4. В какой категории больше всего платных и бесплатных приложений?
# 5. Топ-5 платных приложений с самыми высокими рейтингами и количеством установок?
# 6. Топ-5 бесплатных приложений с самыми высокими рейтингами и количеством установок?
# 7. Какие приложения самые дорогие (и категории)
# 8. Рост количества релизов приложений с 2010 по 2020 год к году \ рост количества релизов новых андроид смартфонов

# %% [markdown]
# **1. Какие 10 лучших категорий которые устанавливаются из магазина Google Play?** \
#  Берем топ 10 по количеству приложений в категориях и уже из них выявляем топ по количеству установок

# %%
df["Category"].unique()
# Out:
# array(['Games', 'Tools', 'Productivity', 'Communication', 'Social',
#        'Libraries & Demo', 'Lifestyle', 'Personalization',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink',
#        'Books & Reference', 'Medical', 'Entertainment', 'Auto & Vehicles',
#        'Photography', 'Health & Fitness', 'Education', 'Shopping',
#        'Board', 'Music & Audio', 'Sports', 'Beauty', 'Business',
#        'Educational', 'Finance', 'News & Magazines', 'Art & Design',
#        'House & Home', 'Events', 'Trivia', 'Weather', 'Word',
#        'Video Players & Editors', 'Music', 'Dating', 'Casino', 'Comics',
#        'Parenting'], dtype=object)

# %%
df["Category"].value_counts().head()
# Out:
# Games            266780
# Education        241068
# Music & Audio    154897
# Tools            143971
# Business         143749
# Name: Category, dtype: int64

# %%
top_category = df["Category"].value_counts().reset_index().rename(columns={"Category" : "Count", "index" : "Category"})
top_category.head(10) #выявлили топ категорий по количеству приложений
# Out:
#             Category   Count
# 0              Games  266780
# 1          Education  241068
# 2      Music & Audio  154897
# 3              Tools  143971
# 4           Business  143749
# 5      Entertainment  138261
# 6          Lifestyle  118321
# 7  Books & Reference  116716
# 8    Personalization   89207
# 9   Health & Fitness   83497

# %%
category_installs = df.groupby(["Category"])[["Installs"]].sum().reset_index()
category_installs #количество установок приложений по категориям
# Out:
#                    Category     Installs
# 0              Art & Design   1116398902
# 1           Auto & Vehicles   1594745418
# 2                    Beauty    404328787
# 3                     Board   3290826164
# 4         Books & Reference   4819175179
# 5                  Business   5236661902
# 6                    Casino   1249613989
# 7                    Comics    397602344
# 8             Communication  43216592414
# 9                    Dating    643267317
# 10                Education   5983815847
# 11              Educational   4730801093
# 12            Entertainment  17108397933
# 13                   Events     73016139
# 14                  Finance   6158477105
# 15             Food & Drink   1623441588
# 16                    Games  96733932092
# 17         Health & Fitness   4586600201
# 18             House & Home    463801748
# 19         Libraries & Demo    289118035
# 20                Lifestyle   5997921096
# 21        Maps & Navigation   2683038830
# 22                  Medical    657119650
# 23                    Music   1630600862
# 24            Music & Audio  14239401798
# 25         News & Magazines   4548786357
# 26                Parenting    244133966
# 27          Personalization   9252971243
# 28              Photography  18998958963
# 29             Productivity  28313922253
# 30                 Shopping   7108586169
# 31                   Social  17165994565
# 32                   Sports   7954121388
# 33                    Tools  71440271217
# 34           Travel & Local   9726222850
# 35                   Trivia   1188962483
# 36  Video Players & Editors  18591154109
# 37                  Weather   2773800062
# 38                     Word   2029143957

# %%
category_installs_sum_games = category_installs.groupby(["Category"]).sum().sort_values('Installs', ascending= False).reset_index()
category_installs_sum_games #объеденили игровые категории в одну
# Out:
#                    Category     Installs
# 0                     Games  96733932092
# 1                     Tools  71440271217
# 2             Communication  43216592414
# 3              Productivity  28313922253
# 4               Photography  18998958963
# 5   Video Players & Editors  18591154109
# 6                    Social  17165994565
# 7             Entertainment  17108397933
# 8             Music & Audio  14239401798
# 9            Travel & Local   9726222850
# 10          Personalization   9252971243
# 11                   Sports   7954121388
# 12                 Shopping   7108586169
# 13                  Finance   6158477105
# 14                Lifestyle   5997921096
# 15                Education   5983815847
# 16                 Business   5236661902
# 17        Books & Reference   4819175179
# 18              Educational   4730801093
# 19         Health & Fitness   4586600201
# 20         News & Magazines   4548786357
# 21                    Board   3290826164
# 22                  Weather   2773800062
# 23        Maps & Navigation   2683038830
# 24                     Word   2029143957
# 25                    Music   1630600862
# 26             Food & Drink   1623441588
# 27          Auto & Vehicles   1594745418
# 28                   Casino   1249613989
# 29                   Trivia   1188962483
# 30             Art & Design   1116398902
# 31                  Medical    657119650
# 32                   Dating    643267317
# 33             House & Home    463801748
# 34                   Beauty    404328787
# 35                   Comics    397602344
# 36         Libraries & Demo    289118035
# 37                Parenting    244133966
# 38                   Events     73016139

# %%
top_category_installs = pd.merge(top_category, category_installs_sum_games, on="Category")
top_10_category_installs = category_installs_sum_games.head(10).sort_values(by=["Installs"], ascending=False)
top_10_category_installs # топ 10 категорий по установкам из топа по количеству в категории
# Out:
#                   Category     Installs
# 0                    Games  96733932092
# 1                    Tools  71440271217
# 2            Communication  43216592414
# 3             Productivity  28313922253
# 4              Photography  18998958963
# 5  Video Players & Editors  18591154109
# 6                   Social  17165994565
# 7            Entertainment  17108397933
# 8            Music & Audio  14239401798
# 9           Travel & Local   9726222850

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of Application")
plt.title("Top 10 Installed Category")
sns.barplot(x=top_10_category_installs["Category"], y=top_10_category_installs["Installs"])
# Out:
# <AxesSubplot: title={'center': 'Top 10 Installed Category'}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# **Ответ:**
# 1.  Games
# 2.  Tools
# 3.  Communication
# 4.  Productivity
# 5.  Photography
# 6.  Video Players & Editors
# 7.  Social
# 8.  Entertainment
# 9.  Music & Audio
# 10. Travel & Local

# %% [markdown]
# **Топ 10 категорий по количеству установок (без учета количества приложений в категории)**

# %%
top_installed_app = category_installs_sum_games
top_10_installed_app = top_installed_app.sort_values(by="Installs",ascending=False).head(10)
top_10_installed_app
# Out:
#                   Category     Installs
# 0                    Games  96733932092
# 1                    Tools  71440271217
# 2            Communication  43216592414
# 3             Productivity  28313922253
# 4              Photography  18998958963
# 5  Video Players & Editors  18591154109
# 6                   Social  17165994565
# 7            Entertainment  17108397933
# 8            Music & Audio  14239401798
# 9           Travel & Local   9726222850

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of Application")
plt.title("Top 10 Installed App")
sns.barplot(x=top_10_installed_app["Category"], y=top_10_installed_app["Installs"])
# Out:
# <AxesSubplot: title={'center': 'Top 10 Installed App'}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# **Ответ:**
# 1.  Games
# 2.  Tools
# 3.  Communication
# 4.  Productivity
# 5.  Photography
# 6.  Video Players & Editors
# 7.  Social
# 8.  Entertainment
# 9.  Music & Audio
# 10. Travel & Local

# %% [markdown]
# **2. Какие категории чаще всего устанавливаются в топ-10?**

# %%
top_10_category = top_category_installs.head(10).sort_values(by=["Count"], ascending=False).reset_index()
top_10_category #топ 10 категорий по количеству приложений и их установки
# Out:
#    index           Category   Count     Installs
# 0      0              Games  266780  96733932092
# 1      1          Education  241068   5983815847
# 2      2      Music & Audio  154897  14239401798
# 3      3              Tools  143971  71440271217
# 4      4           Business  143749   5236661902
# 5      5      Entertainment  138261  17108397933
# 6      6          Lifestyle  118321   5997921096
# 7      7  Books & Reference  116716   4819175179
# 8      8    Personalization   89207   9252971243
# 9      9   Health & Fitness   83497   4586600201

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of Application")
plt.title("Top 10 Category")
sns.barplot(x=top_10_category["Category"], y=top_10_category["Count"])
# Out:
# <AxesSubplot: title={'center': 'Top 10 Category'}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# **Ответ:**
# 1.  Games
# 2.  Education
# 3.  Music & Audio
# 4.  Tools
# 5.  Business
# 6.  Entertainment
# 7.  Lifestyle
# 8.  Books & Reference
# 9.  Personalization
# 10.  Health & Fitness

# %% [markdown]
# # **Анализ:**
# Из двух приведенных выше графиков видно, что максимальное количество приложений в Google Play Store попадает под категории "Games", "Music & Audio", "Tools", "Business", "Entertainment" и т.д. Однако, когда дело доходит до установок, сценарий меняется. Максимальное количество установленных приложений относится к категориям "Games", "Education", "Music & Audio", "Tools", "Business" и т.д.

# %% [markdown]
# **Визуализация общего количества категорий и количества приложений в каждой категории**

# %%
plt.figure(figsize = (14,7))
plt.xticks(rotation = 90)
plt.xlabel("Category")
plt.ylabel("Number of Applications")
plt.title("Total Categories and Count of Applications in each Category")
sns.barplot(x = top_category_installs.Category, y = top_category_installs.Count)
# Out:
# <AxesSubplot: title={'center': 'Total Categories and Count of Applications in each Category'}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# **Визуализация общего количества категорий и установленного приложения в каждой категории**

# %%
top_category_installed = top_category_installs.sort_values(by="Installs", ascending=False)
plt.figure(figsize = (16,8))
plt.xticks(rotation = 90)
plt.xlabel("Category")
plt.ylabel("Number of Applications")
plt.title("Total Categories and Installation of Applications in each Category")
sns.barplot(x = top_category_installed.Category, y = top_category_installed.Installs)
# Out:
# <AxesSubplot: title={'center': 'Total Categories and Installation of Applications in each Category'}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# **3. Какая категория имеет самый высокий рейтинг?**

# %% [markdown]
# **Распределение рейтинга:**

# %%
plt.figure(figsize = (14,7))
g = sns.kdeplot(df.Rating, color = "Blue", fill = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title("Distribution of Rating", size = 20)
# Out:
# Text(0.5, 1.0, 'Distribution of Rating')

# %%
plt.title("Rating")
sns.histplot(df.Rating, kde = True, bins = 5)
# Out:
# <AxesSubplot: title={'center': 'Rating'}, xlabel='Rating', ylabel='Count'>

# %% [markdown]
# # **Анализ:**
# Приведенные выше два графика показывают, что большая часть приложений в наборе данных не была оценена пользователями. Однако, также заметно, что когда пользователи все-таки ставят оценку, они, как правило, ставят высокую оценку - 4 или выше.

# %%
category_rating = df.groupby(["Category"])[["Rating"]].mean().sort_values(by="Rating", ascending=False).reset_index()
category_rating.head(10)
# Out:
#                   Category    Rating
# 0                   Casino  3.279682
# 1                  Weather  3.120171
# 2  Video Players & Editors  2.903842
# 3                     Word  2.902076
# 4                   Comics  2.864906
# 5                    Board  2.782275
# 6          Personalization  2.758774
# 7                    Games  2.703621
# 8                    Music  2.662008
# 9                   Trivia  2.526178

# %%
plt.figure(figsize = (14,7))
plt.xticks(rotation = 90)
plt.xlabel("Category")
plt.ylabel("Rating")
plt.title("All Category Rating")
sns.barplot(x = category_rating["Category"], y = category_rating["Rating"])
# Out:
# <AxesSubplot: title={'center': 'All Category Rating'}, xlabel='Category', ylabel='Rating'>

# %% [markdown]
# **Ответ:**
# Приведенный выше график показывает, что категория **Role Playing** имеет самый высокий средний рейтинг по сравнению с другими категориями.

# %% [markdown]
# **4. В какой категории больше всего платных и бесплатных приложений?**

# %% [markdown]
# # **Соотношение платных к бесплатным:**

# %%
sns.countplot(x='Free', data=df)
plt.title('Free vs Paid Apps')
plt.xlabel('Free')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **Распределение рейтингов для бесплатных и платных приложений**

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(data=df[df['Free'] == True]['Rating'], label='Free Apps', fill=True)
sns.kdeplot(data=df[df['Free'] == False]['Rating'], label='Paid Apps', fill=True)
plt.title('Distribution of Ratings for Free and Paid Apps')
plt.xlabel('Rating')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
df["Type"] = "Paid"
df.loc[(df["Free"] == True, "Type")] = "Free"

# %%
df.Type.value_counts()
# Out:
# Free    2267619
# Paid      44929
# Name: Type, dtype: int64

# %%
category_paid_free = pd.crosstab(df["Category"],df["Type"])
category_paid_free.head(10)
# Out:
# Type                 Free  Paid
# Category
# Art & Design        18364   172
# Auto & Vehicles     17994   282
# Beauty              11757    14
# Board               10223   364
# Books & Reference  113119  3597
# Business           143079   670
# Casino               5000    76
# Comics               2806    56
# Communication       47690   467
# Dating               6498    24

# %%
category_paid_free.sort_values(by="Paid", ascending=False).head(10)
# Out:
# Type                 Free  Paid
# Category
# Games              260210  6570
# Education          234521  6547
# Personalization     83440  5767
# Tools              139894  4077
# Books & Reference  113119  3597
# Productivity        77950  1731
# Music & Audio      153373  1524
# Travel & Local      65865  1414
# Health & Fitness    82085  1412
# Entertainment      136880  1381

# %%
category_paid_free.plot(kind = "bar", stacked = True, figsize = (14,7))
plt.xlabel("Category", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
plt.title("Free and Paid Apps in Category")
# Out:
# Text(0.5, 1.0, 'Free and Paid Apps in Category')

# %%
pd.crosstab(df["Category"],df["Type"]).apply(lambda x: round(x/x.sum()*100,1), axis=1).sort_values(by="Paid", ascending=False)
# Out:
# Type                     Free  Paid
# Category
# Personalization          93.5   6.5
# Educational              94.8   5.2
# Medical                  95.7   4.3
# Board                    96.6   3.4
# Weather                  96.7   3.3
# Books & Reference        96.9   3.1
# Sports                   97.2   2.8
# Tools                    97.2   2.8
# Education                97.3   2.7
# Music                    97.4   2.6
# Parenting                97.4   2.6
# Games                    97.5   2.5
# Maps & Navigation        97.6   2.4
# Video Players & Editors  97.6   2.4
# Productivity             97.8   2.2
# Travel & Local           97.9   2.1
# Word                     97.9   2.1
# Comics                   98.0   2.0
# Health & Fitness         98.3   1.7
# Photography              98.4   1.6
# Casino                   98.5   1.5
# Auto & Vehicles          98.5   1.5
# Libraries & Demo         98.6   1.4
# Lifestyle                98.9   1.1
# Music & Audio            99.0   1.0
# Entertainment            99.0   1.0
# Communication            99.0   1.0
# Finance                  99.1   0.9
# Trivia                   99.1   0.9
# Art & Design             99.1   0.9
# Social                   99.5   0.5
# Business                 99.5   0.5
# House & Home             99.6   0.4
# Dating                   99.6   0.4
# News & Magazines         99.7   0.3
# Food & Drink             99.7   0.3
# Events                   99.9   0.1
# Shopping                 99.9   0.1
# Beauty                   99.9   0.1

# %% [markdown]
#  **Ответ:**
# В категории "Personalization" самое большое количество платных приложений в списке.\
# Доля категории Personalization в списке платных приложений составляет 6,5%, что является самым высоким показателем среди всех категорий.

# %% [markdown]
# **5. Топ-5 платных приложений с самыми высокими рейтингами и количеством установок**

# %%
df["Installs"].max()
# Out:
# 10000000000

# %%
paid_installs_apps = df[(df.Type=="Paid") & (df.Installs >= 5000000)]
paid_installs_apps
# Out:
#                                                   App Name  \
# 6302                                            True Skate
# 508696                                       Hitman Sniper
# 837351                                           Minecraft
# 1859983  Stickman Legends-Shadow Fight Premium Offline ...
# 1933739                     Poweramp Full Version Unlocker
# 2052997  League of Stickman 2020- Ninja Arena PVP(Dream...
#
#                                                App Id       Category  Rating  \
# 6302                           com.trueaxis.trueskate         Sports     4.4
# 508696     com.squareenixmontreal.hitmansniperandroid          Games     4.4
# 837351                         com.mojang.minecraftpe          Games     4.6
# 1859983  com.zitga.ninja.stickman.legends.shadow.wars          Games     4.3
# 1933739                 com.maxmpz.audioplayer.unlock  Music & Audio     4.2
# 2052997                          me.dreamsky.stickman          Games     4.1
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs   Free  \
# 6302         191460.0   5000000         5000000.0           7040478  False
# 508696       854992.0  10000000        10000000.0          24958893  False
# 837351      4132618.0  10000000        10000000.0          36183322  False
# 1859983      235762.0  10000000        10000000.0          13264461  False
# 1933739       55111.0   5000000         5000000.0           5481771  False
# 2052997       65269.0   5000000         5000000.0           5621942  False
#
#          Price  ...     Developer Id  \
# 6302      1.99  ...        True Axis
# 508696    0.99  ...  SQUARE ENIX LTD
# 837351    7.49  ...           Mojang
# 1859983   0.99  ...            ZITGA
# 1933739   4.99  ...           Max MP
# 2052997   0.99  ...         DreamSky
#
#                                          Developer Email      Released  \
# 6302                       support.android@trueskate.com  Jul 19, 2013
# 508696   support@square-enix-montreal.mail.helpshift.com   Jun 3, 2015
# 837351                                help@minecraft.net  Aug 15, 2011
# 1859983                     StickmanLegends@zitga.com.vn  May 10, 2017
# 1933739                        poweramp.maxmpz@gmail.com   Nov 7, 2010
# 2052997                     leagueofstickman@dreamsky.me   Sep 3, 2016
#
#          Last Updated Content Rating Ad Supported In App Purchases  \
# 6302     Jun 07, 2021       Everyone         True             True
# 508696   Aug 24, 2020     Mature 17+         True             True
# 837351   May 27, 2021   Everyone 10+        False             True
# 1859983  Jun 08, 2021   Everyone 10+         True             True
# 1933739  Jan 20, 2020       Everyone        False            False
# 2052997  Dec 30, 2020           Teen         True             True
#
#         Editors Choice         Scraped Time  Type
# 6302             False  2021-06-15 20:25:39  Paid
# 508696            True  2021-06-16 04:42:58  Paid
# 837351            True  2021-06-16 09:47:13  Paid
# 1859983          False  2021-06-16 06:24:42  Paid
# 1933739          False  2021-06-16 07:28:13  Paid
# 2052997          False  2021-06-16 09:12:31  Paid
#
# [6 rows x 23 columns]

# %%
paid_installs_rating_apps = paid_installs_apps.groupby(["App Name"])[["Rating"]].max().sort_values(by="Rating",ascending = False)
paid_installs_rating_apps
# Out:
#                                                     Rating
# App Name
# Minecraft                                              4.6
# Hitman Sniper                                          4.4
# True Skate                                             4.4
# Stickman Legends-Shadow Fight Premium Offline Game     4.3
# Poweramp Full Version Unlocker                         4.2
# League of Stickman 2020- Ninja Arena PVP(Dreamsky)     4.1

# %% [markdown]
# **Ответ:**
# * Minecraft
# * Hitman Sniper
# * True Skate
# * Stickman Legends-Shadow Fight Premium Offline Game
# * Poweramp Full Version Unlocker
# * League of Stickman 2020- Ninja Arena PVP(Dreamsky)

# %% [markdown]
# **6. Топ-5 бесплатных приложений с самыми высокими рейтингами и количеством установок**

# %%
free_installs_apps = df[(df.Type=="Free") & (df.Installs >= 5000000)]
free_installs_apps
# Out:
#                                                   App Name  \
# 92            Car Games Revival: Car Racing Games for Kids
# 291                                          Taxsee Driver
# 472                            MONOMAX บริการดูหนังออนไลน์
# 561                            Web Browser & Fast Explorer
# 631                                           Piano Melody
# ...                                                    ...
# 2312253                                    Bubble Champion
# 2312298                                         Mp3 Player
# 2312316                     Design It Girl - Fashion Salon
# 2312677  Modern Strike : Multiplayer FPS - Critical Action
# 2312932                            Hopeless 2: Cave Escape
#
#                                                    App Id           Category  \
# 92       com.lf.real.extreme.suv.offroad.drive.games.free              Games
# 291                                     com.taxsee.driver  Maps & Navigation
# 472                                  com.doonung.activity      Entertainment
# 561                             fast.explorer.web.browser             Social
# 631                        com.veitch.themelodymaster.pmf          Education
# ...                                                   ...                ...
# 2312253                                   champion.bubble              Games
# 2312298            mp3.music.download.player.music.search      Music & Audio
# 2312316                        com.tabtale.tailorboutique              Games
# 2312677                        com.shoot.hotheadgame.anti              Games
# 2312932                               com.upopa.hopeless2              Games
#
#          Rating  Rating Count  Installs  Minimum Installs  Maximum Installs  \
# 92          3.9       55218.0  10000000        10000000.0          30052692
# 291         4.4         246.0   5000000         5000000.0           6864573
# 472         3.7       22803.0   5000000         5000000.0           5278071
# 561         4.4      103945.0  10000000        10000000.0          13629503
# 631         4.2       66049.0  10000000        10000000.0          13882293
# ...         ...           ...       ...               ...               ...
# 2312253     4.2       52395.0  10000000        10000000.0          12892286
# 2312298     4.6      824440.0  10000000        10000000.0          29468091
# 2312316     3.6       87553.0  10000000        10000000.0          22226621
# 2312677     3.9       78351.0  10000000        10000000.0          24015387
# 2312932     4.3      103466.0   5000000         5000000.0           7274660
#
#          Free  Price  ...                    Developer Id  \
# 92       True    0.0  ...                 Abstron Pvt Ltd
# 291      True    0.0  ...                    Technologiya
# 472      True    0.0  ...  Mono Streaming Company Limited
# 561      True    0.0  ...                        iJoysoft
# 631      True    0.0  ...                 Learn To Master
# ...       ...    ...  ...                             ...
# 2312253  True    0.0  ...         Bubble Shooter Artworks
# 2312298  True    0.0  ...                      accountlab
# 2312316  True    0.0  ...                         TabTale
# 2312677  True    0.0  ...            Enjoy.GameStudio.Fun
# 2312932  True    0.0  ...                     Upopa Games
#
#                     Developer Email      Released  Last Updated  \
# 92           info.abstron@gmail.com   Nov 9, 2016  Jun 12, 2021
# 291               support@taxsee.ru  Oct 27, 2011  May 24, 2021
# 472        monofilm.movie@gmail.com           NaN  Jun 04, 2021
# 561         smartchen2015@gmail.com  May 19, 2016  Apr 09, 2021
# 631      LearnToMasterLtd@gmail.com  Nov 26, 2010  Jun 09, 2021
# ...                             ...           ...           ...
# 2312253           support@ilyon.net  Oct 19, 2017  Jun 01, 2021
# 2312298  sreejaksreeja007@gmail.com   Apr 1, 2016  May 30, 2021
# 2312316         support@tabtale.com  Jan 10, 2017  Apr 28, 2021
# 2312677     fun.game.jhon@gmail.com   Aug 6, 2020  May 12, 2021
# 2312932           support@upopa.com  Oct 29, 2015  Mar 06, 2017
#
#         Content Rating Ad Supported In App Purchases Editors Choice  \
# 92            Everyone         True             True          False
# 291           Everyone        False            False          False
# 472               Teen        False            False          False
# 561           Everyone         True            False          False
# 631           Everyone         True             True          False
# ...                ...          ...              ...            ...
# 2312253       Everyone         True             True          False
# 2312298       Everyone         True            False          False
# 2312316       Everyone         True             True          False
# 2312677           Teen         True             True          False
# 2312932           Teen         True             True          False
#
#                 Scraped Time  Type
# 92       2021-06-15 20:19:40  Free
# 291      2021-06-15 20:19:53  Free
# 472      2021-06-15 20:20:03  Free
# 561      2021-06-15 20:20:08  Free
# 631      2021-06-15 20:20:12  Free
# ...                      ...   ...
# 2312253  2021-06-16 12:58:42  Free
# 2312298  2021-06-16 12:58:44  Free
# 2312316  2021-06-16 12:58:45  Free
# 2312677  2021-06-16 12:59:05  Free
# 2312932  2021-06-16 12:59:18  Free
#
# [14288 rows x 23 columns]

# %%
free_installs_rating_apps = free_installs_apps.groupby(["App Name"])[["Rating"]].max().sort_values(by="Rating",ascending = False).head(5)
free_installs_rating_apps
# Out:
#                                                  Rating
# App Name
# Maps Master for Minecraft                           5.0
# Photo Frame                                         5.0
# Video maker with photo & music                      5.0
# Kuku FM - Love Stories, Audio Books & Podcasts      5.0
# Plank Workout at Home - 30 Days Plank Challenge     4.9

# %% [markdown]
# **Ответ:**
# * Maps Master for Minecraft
# * Photo Frame
# * Video maker with photo & music
# * Kuku FM- Love Stories
# * Audio Books & Podcasts
# * Plank Workout at Home

# %% [markdown]
# **7. Какие приложения самые дорогие (и категории)**

# %%
top_10_price_app = df[['App Name', 'Price']].sort_values('Price', ascending=False).head(10)
top_10_price_app
# Out:
#                                                App Name   Price
# 544468                                     MESH Connect  400.00
# 1580432                                 Baby Nightmares  399.99
# 268776                                            Taxes  399.99
# 644212                Challenge Impossible Ball for you  399.99
# 1444845                      Plasma duct - Premium Game  399.99
# 1312551                                         Success  399.99
# 1859780                                            AudD  399.99
# 789532                            Acid Reflux Treatment  399.99
# 817106                           Most Expensive Clicker  399.99
# 829385   Premium Luxury Watches - Luxury Watches Brands  399.99

# %%
top_10_price_category = df.groupby(["Category"])[["Price"]].sum().round(1).sort_values('Price', ascending=False).head(10)
top_10_price_category
# Out:
#                      Price
# Category
# Education          39355.8
# Games              27068.3
# Medical            22810.7
# Books & Reference  22554.7
# Tools              21123.6
# Sports             10753.7
# Productivity       10611.9
# Personalization     9737.6
# Lifestyle           8986.2
# Health & Fitness    8258.4

# %% [markdown]
# **8. Рост количества релизов приложений с 2010 по 2020 год к году \ рост количества релизов новых андроид смартфонов**

# %% [markdown]
# Приложения:

# %%
df['Released'].head() #даты релиза
# Out:
# 0    Feb 26, 2020
# 1    May 21, 2020
# 2     Aug 9, 2019
# 3    Sep 10, 2018
# 4    Feb 21, 2020
# Name: Released, dtype: object

# %%
released_to_datetime = pd.to_datetime(df['Released'])

# %%
released_to_datetime
# Out:
# 0         2020-02-26
# 1         2020-05-21
# 2         2019-08-09
# 3         2018-09-10
# 4         2020-02-21
#              ...
# 2312939          NaT
# 2312940   2018-01-17
# 2312941   2018-08-19
# 2312942   2016-08-01
# 2312943   2019-08-09
# Name: Released, Length: 2312548, dtype: datetime64[ns]

# %%
apps_years = released_to_datetime.dropna().dt.year.value_counts(ascending = True).drop(2021)
#2021 не используем, так как данные только по июнь
apps_years #количество релизов ежегодно
# Out:
# 2010      4639
# 2011     14354
# 2012     25736
# 2013     42473
# 2014     71810
# 2015    115431
# 2016    167107
# 2017    259683
# 2018    334558
# 2019    480632
# 2020    544872
# Name: Released, dtype: int64

# %%
apps_years.plot(kind = 'bar') #визуализация роста количества релизов приложений ежегодно
# Out:
# <AxesSubplot: >

# %%
round(apps_years.pct_change()*100,2) #проценты увеличения количества релизов из года в год относительно предыдущего годa
# Out:
# 2010       NaN
# 2011    209.42
# 2012     79.29
# 2013     65.03
# 2014     69.07
# 2015     60.75
# 2016     44.77
# 2017     55.40
# 2018     28.83
# 2019     43.66
# 2020     13.37
# Name: Released, dtype: float64

# %%
average_percentage_app = round(apps_years.pct_change().mean()*100,2)
average_percentage_app
# Out:
# 66.96

# %% [markdown]
# Андроид смартфоны:

# %%
df_android = pd.read_csv("Android Phones.csv")

# %%
df_android.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     1332 non-null   object
#  1   Brand    1332 non-null   object
#  2   Release  1325 non-null   object
#  3   Version  1332 non-null   object
# dtypes: object(4)
# memory usage: 41.8+ KB

# %%
df_android.shape
# Out:
# (1332, 4)

# %%
df_android.Release.unique()
# Out:
# array(['2015/11', '2016/08', '2016/10', '2017/03', '2017/04', '2017/12',
#        '2018/06', '2018/08', '2018/10', '2019/01', '2019/07', '2011/01',
#        '2017/08', 'Unreleased', '2013/04', '2015/01', '2020/08',
#        '2021/10', '2021/07', '2017/09', '2013/08', '2013/03', '2014/07',
#        '2012/08', '2020/09', '2008/09', '2009/05', '2009/07', '2009/09',
#        '2010/02', '2010/03', '2010/04', '2010/05', '2010/06', '2010/10',
#        '2010/11', '2011/02', '2011/03', '2011/04', '2011/05', '2011/06',
#        '2011/07', '2011/10', '2011/11', '2012/04', '2012/05', '2012/06',
#        '2012/07', '2012/10', '2012/11', '2012/12', '2013/01', '2013/06',
#        '2013/07', '2013/09', '2013/10', '2013/12', '2014/01', '2014/02',
#        '2014/03', '2014/04', '2014/05', '2014/06', '2014/09', '2014/10',
#        '2014/11', '2014/12', '2015/03', '2015/04', '2015/05', '2015/06',
#        '2015/07', '2015/08', '2015/10', '2016/01', '2016/03', '2016/04',
#        '2016/05', '2016/06', '2016/09', '2016/12', '2016/11', '2017/02',
#        '2017/06', '2017/07', '2017/11', '2018/01', '2018/09', '2018/12',
#        '2019/06', '2019/08', '2019/10', '2019/11', '2020/02', '2020/06',
#        '2020/10', '2021/01', '2021/05', '2011/09', '2014/08', '2016/07',
#        '2017/05', '2017/10', '2018/04', '2018/05', '2018/07', '2018/11',
#        '2019/04', '2019/05', '2019/09', '2020/03', '2020/04', '2020/05',
#        '2020/07', '2021/03', '2021/04', '2021/06', '2021/08', '2021/11',
#        '2021/12', '2022/01', '2010/07', '2010/09', '2013/02', '2018/03',
#        '2019/03', '2019/12', '2020/11', '2020/12', '2021/02', '2017/01',
#        '2013/11', '2015/09', '2016/02', '2009/11', '2012/01', '2015/02',
#        '2011/12', '2021/09', '2009/10', '2010/08', '2012/02', '2012/09',
#        '2020/01', nan, '2010/01', '2010/12', '2019/02', '2018/02',
#        '2021/8', '2015/12', '2009/04', '2012/03'], dtype=object)

# %%
android_year = df_android[df_android['Release'].str[0].isin(['2'])].Release.str[:4].astype(str).astype(int)
android_year
# Out:
# 0       2015
# 1       2016
# 2       2016
# 3       2017
# 4       2017
#         ...
# 1327    2021
# 1328    2021
# 1329    2021
# 1330    2021
# 1331    2021
# Name: Release, Length: 1322, dtype: int32

# %%
android_height = android_year.value_counts(ascending=True).sort_index().drop([2008,2009,2021,2022])
android_height
# Out:
# 2010     31
# 2011     49
# 2012     62
# 2013     60
# 2014     86
# 2015    109
# 2016    112
# 2017    103
# 2018    128
# 2019    157
# 2020    236
# Name: Release, dtype: int64

# %%
android_height.plot(kind = 'bar') #визуализация роста количества андроидов ежегодно
# Out:
# <AxesSubplot: >

# %%
average_percentage_android = round(android_height.pct_change().mean()*100,2)
average_percentage_android
# Out:
# 24.34

# %%
ratio_apps_android = round(average_percentage_app/average_percentage_android,2)
ratio_apps_android
# Out:
# 2.75

# %% [markdown]
# **Ответ**: \
# Средний процент роста количества релизов новых приложений в Google Play Store из года в год примерно в 2.75 раза выше, \
#  чем средний процент роста релизов новых андроид смартфонов

# %% [markdown]
# ![image.png](let_me_in.jpg)
